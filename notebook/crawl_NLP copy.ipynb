# %% [markdown]
# # NER Laporan Warga (Jalan Rusak, Lampu Padam, Sampah) — Draft Notebook Lengkap
#
# **Fitur utama**
# - Koleksi data via **X API (resmi)** *opsional* + opsi **CSV dummy** jika belum punya akses.
# - **Pre‑processing**: pembersihan teks, de‑identifikasi handle/URL, normalisasi tanggal.
# - **Weak Supervision (Baseline Rules)**: regex & gazetteer untuk pre‑label (ISSUE_TYPE, DATETIME, SEVERITY, LOCATION*).
# - Alur **anotasi NER** dengan **Doccano**: ekspor *template* dan impor hasil anotasi (JSONL spans) → konversi ke **BIO**.
# - **Fine‑tuning IndoBERT** (HuggingFace) untuk **token classification**.
# - **Evaluasi** dengan **seqeval** (entity‑level F1 per label + macro).
# - **Inferensi** → JSON terstruktur (issue_type, lokasi, datetime, severity, dll.).
# - (Opsional) **Geocoding** menggunakan Nominatim (OpenStreetMap).
# - (Opsional) **FastAPI** endpoint `/extract` untuk integrasi.
#
# > **Etika/ToS:** Gunakan **X API resmi**. Hindari scraping HTML/cookies yang melanggar ToS.

# %%
# !pip install -U pip
# !pip install transformers datasets accelerate seqeval evaluate tqdm rich sentencepiece dateparser rapidfuzz unidecode pydantic==2.* python-dotenv requests ujson pandas scikit-learn matplotlib
# # Opsional (CRF)
# # !pip install sklearn-crfsuite

import os, json, random, re, time, math
from dataclasses import dataclass
from typing import List, Dict, Any, Tuple

import numpy as np
import pandas as pd

BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR = os.path.join(DATA_DIR, 'raw')
PROCESSED_DIR = os.path.join(DATA_DIR, 'processed')


for d in [DATA_DIR, RAW_DIR, PROCESSED_DIR]:
    os.makedirs(d, exist_ok=True)

# %%
# !dpkg --configure -a
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
# !NODE_MAJOR=18 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
# !sudo apt-get update
# !sudo apt-get install nodejs -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,628 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 https://cli.github.com/packages stable InRelease
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,371 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,609 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:13 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [81.0 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,274 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,014 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,807 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,577 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,690 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:21 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,307 kB]
# Fetched 30.2 MB in 4s (8,340 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.20).
# gnupg is already the newest version (2.2.27-3ubuntu2.4).
# gnupg set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_18.x nodistro main
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:4 https://deb.nodesource.com/node_18.x nodistro InRelease [12.1 kB]
# Hit:5 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 https://deb.nodesource.com/node_18.x nodistro/main amd64 Packages [11.7 kB]
# Hit:13 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Fetched 23.9 kB in 1s (17.1 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 29.7 MB of archives.
# After this operation, 187 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_18.x nodistro/main amd64 nodejs amd64 18.20.8-1nodesource1 [29.7 MB]
# Fetched 29.7 MB in 0s (60.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 126441 files and directories currently installed.)
# Preparing to unpack .../nodejs_18.20.8-1nodesource1_amd64.deb ...
# Unpacking nodejs (18.20.8-1nodesource1) ...
# Setting up nodejs (18.20.8-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
auth_token = 'c84ba206331211b33f2226e8a11dd9202176ec22' #isi dengan auth token twitter cookies
filename = 'data_jalan.csv'
keyword = 'jalan rusak since:2023-09-01 until:2025-09-01 lang:id'
limit = 1000



# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{keyword}" --tab "LATEST" -l {limit} --token {auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: jalan rusak since:2023-09-01 until:2025-09-01 lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 18
#
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 38
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 58
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 78
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 98
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 117
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 137
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 157
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 177
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 197
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 217
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 237
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 257
#
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 277
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 297
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 317
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 337
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 357
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 377
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 395
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 414
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 434
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 454
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 474
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 494
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 514
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 534
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 554
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 574
#
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 592
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 612
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 632
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 652
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 672
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 692
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 712
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 732
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 752
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 772
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 792
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 812
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 832
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 851
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 871
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 891
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 911
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 931
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 951
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 971
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 991
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_jalan.csv
# Total tweets saved: 1011
# Got 1011 tweets, done scrolling...
# ⠙

# %%
auth_token = 'c84ba206331211b33f2226e8a11dd9202176ec22' #isi dengan auth token twitter cookies
filename = 'data_lampu.csv'
keyword = 'lampu jalan mati since:2023-09-01 until:2025-09-01 lang:id'
limit = 1000



# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{keyword}" --tab "LATEST" -l {limit} --token {auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: lampu jalan mati since:2023-09-01 until:2025-09-01 lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 39
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 59
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 79
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 99
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 119
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 139
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 159
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 179
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 199
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 219
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 239
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 259
#
# -- Scrolling... (1) (2) (3) (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 279
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 299
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 319
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 339
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 359
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 379
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 399
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 419
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 439
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 459
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 479
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 498
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 518
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 538
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 558
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 578
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 598
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 618
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 638
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 658
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 678
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 698
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 718
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_lampu.csv
# Total tweets saved: 738
# [v2.6.1] Error parsing response json: {"_type":"Response","_guid":"response@6deb025502850777807e0f93b5548f25"}
# [v2.6.1] Most likely, you have already exceeded the Twitter rate limit. Read more on https://x.com/elonmusk/status/1675187969420828672.
# [v2.6.1] TimeoutError: page.click: Timeout 60000ms exceeded.
# Call log:
#   - waiting for locator('text=Retry')
#
# Keywords: lampu jalan mati since:2023-09-01 until:2025-09-01 lang:id
# Twitter Harvest v 2.6.1
#
# If you need help, please send this error screenshot to the maintainer, it was saved to "/content/tweets-data/Error-28-09-2025_16-20-26.png"
# ⠙

# %%
auth_token = 'c84ba206331211b33f2226e8a11dd9202176ec22' #isi dengan auth token twitter cookies
filename = 'data_sampah.csv'
keyword = 'sampah menumpuk since:2023-09-01 until:2025-09-01 lang:id'
limit = 500



# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{keyword}" --tab "LATEST" -l {limit} --token {auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: sampah menumpuk since:2023-09-01 until:2025-09-01 lang:id
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 80
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 100
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 120
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 140
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 160
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 180
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 200
#
# -- Scrolling... (1) (2) (3) (4) (5)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 220
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 240
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 260
#
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 280
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 300
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 320
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 340
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 360
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 380
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 400
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 420
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 440
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 460
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 480
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_sampah.csv
# Total tweets saved: 500
# Got 500 tweets, done scrolling...
# ⠙

# %%
auth_token = 'c84ba206331211b33f2226e8a11dd9202176ec22' #isi dengan auth token twitter cookies
filename = 'data_banjir.csv'
keyword = 'banjir since:2023-09-01 until:2025-09-01 lang:id'
limit = 500



# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{keyword}" --tab "LATEST" -l {limit} --token {auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2)
# Filling in keywords: banjir since:2023-09-01 until:2025-09-01 lang:id
#
#  (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 17
# [v2.6.1] No more tweets found, please check your search criteria and csv file result
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 35
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 55
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 70
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 90
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 110
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 130
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 150
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 170
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 190
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 209
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 229
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 245
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 265
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 285
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 305
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 325
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 345
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 364
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 384
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 404
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 424
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 444
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 464
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 484
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_banjir.csv
# Total tweets saved: 504
# Got 504 tweets, done scrolling...
# ⠙

# %%
auth_token = 'c84ba206331211b33f2226e8a11dd9202176ec22' #isi dengan auth token twitter cookies
filename = 'data_pohon.csv'
keyword = 'pohon tumbang since:2023-09-01 until:2025-09-01 lang:id'
limit = 500



# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{keyword}" --tab "LATEST" -l {limit} --token {auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: pohon tumbang since:2023-09-01 until:2025-09-01 lang:id
#
#  (4) (5) (6) (7)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 20
#
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 80
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 100
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 120
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 140
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 160
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 180
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 200
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 220
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 239
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 259
#
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 279
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 299
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 319
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 339
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 359
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 379
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 399
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 419
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 439
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 459
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 479
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 499
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/data_pohon.csv
# Total tweets saved: 519
# Got 519 tweets, done scrolling...
# ⠙

# %%
# List of filenames to combine
filenames = [
    'data_jalan.csv',
    'data_lampu.csv',
    'data_sampah.csv',
    'data_banjir.csv',
    'data_pohon.csv'
]

# Directory where the files are saved
data_dir = '/content/tweets-data'

# List to hold individual DataFrames
dfs = []

# Read each CSV file and append its DataFrame to the list
for filename in filenames:
    filepath = os.path.join(data_dir, filename)
    if os.path.exists(filepath):
        df = pd.read_csv(filepath)
        dfs.append(df)
    else:
        print(f"File not found: {filepath}")

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined DataFrame to a new CSV file
output_filename = 'combined_data.csv'
output_filepath = os.path.join(RAW_DIR, output_filename) # Use RAW_DIR from the first code cell
combined_df.to_csv(output_filepath, index=False)

print(f"Combined data saved to: {output_filepath}")

# Display the first few rows of the combined DataFrame
display(combined_df.head())

# Print the shape of the combined DataFrame
print(f"Shape of the combined DataFrame: {combined_df.shape}")
# Out:
# Combined data saved to: /content/data/raw/combined_data.csv
#    conversation_id_str                      created_at  favorite_count  \
# 0  1962299990761734245  Sun Aug 31 23:42:30 +0000 2025               0
# 1  1962298947650920833  Sun Aug 31 23:38:21 +0000 2025               1
# 2  1962296611000000927  Sun Aug 31 23:29:04 +0000 2025              16
# 3  1962285953726509097  Sun Aug 31 22:46:43 +0000 2025               1
# 4  1962179468489113897  Sun Aug 31 22:33:25 +0000 2025               0
#
#                                            full_text               id_str  \
# 0  tapi sumpah guyss jgn rusak fasilitas umum kar...  1962299990761734245
# 1  Beneran gw pas jalan kerja di gojek nangis sed...  1962298947650920833
# 2  Mobil Dinas Kesulitan di Jalan Rusak Warga Pil...  1962296611000000927
# 3  helehhhh prett bgt orang jepara aslinya gamau ...  1962285953726509097
# 4  @yorselves Apakah adil rakyat yg mati gegara l...  1962282606768341410
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0       NaN                     NaN   in       NaN            0            0
# 1       NaN                     NaN   in       NaN            0            0
# 2       NaN                     NaN   in       NaN            1            1
# 3       NaN                     NaN   in       NaN            0            0
# 4       NaN               yorselves   in       NaN            0            0
#
#    retweet_count                                          tweet_url  \
# 0              0  https://x.com/undefined/status/196229999076173...
# 1              0  https://x.com/undefined/status/196229894765092...
# 2              2  https://x.com/undefined/status/196229661100000...
# 3              0  https://x.com/undefined/status/196228595372650...
# 4              0  https://x.com/undefined/status/196228260676834...
#
#            user_id_str  username
# 0  1693985563450433536       NaN
# 1  1574439522053804032       NaN
# 2             41730943       NaN
# 3  1121031670289690625       NaN
# 4           1393643270       NaN
# Shape of the combined DataFrame: (3272, 15)

# %%
# !pip install sastrawi
# !pip install wordcloud
# !pip install nltk
# !pip install emoji
# !pip install nlp-id
# !pip install tqdm
# !pip install transformers
# !pip install torch
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 11.2 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Collecting emoji
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 16.5 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0
# Collecting nlp-id
#   Downloading nlp_id-0.1.20.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting huggingface-hub==0.34.4 (from nlp-id)
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.12/dist-packages (from nlp-id) (3.9.1)
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (from nlp-id) (2.0.2)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.12/dist-packages (from nlp-id) (1.6.1)
# Collecting scipy==1.15.3 (from nlp-id)
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.2 MB/s eta 0:00:00
# Collecting wget==3.2 (from nlp-id)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->nlp-id) (1.1.10)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1->nlp-id) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1->nlp-id) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk==3.9.1->nlp-id) (2024.11.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.6.1->nlp-id) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.34.4->nlp-id) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.34.4->nlp-id) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.34.4->nlp-id) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.34.4->nlp-id) (2025.8.3)
# Downloading nlp_id-0.1.20.0-py3-none-any.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 11.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 24.2 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 19.7 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=e59e87de35121dc78c5cb6c662d3778f11e42d6fef5d4c5663d737c1e52c3f39
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget, scipy, huggingface-hub, nlp-id
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.35.0
#     Uninstalling huggingface-hub-0.35.0:
#       Successfully uninstalled huggingface-hub-0.35.0
# Successfully installed huggingface-hub-0.34.4 nlp-id-0.1.20.0 scipy-1.15.3 wget-3.2
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.56.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)

# %%
# Import library yang diperlukan
import pandas as pd
import numpy as np
import re
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
import emoji
from nltk.tokenize import word_tokenize
from tqdm import tqdm

# Library untuk preprocessing bahasa Indonesia
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from nlp_id.tokenizer import Tokenizer
from nlp_id.stopword import StopWord

# Download NLTK data
nltk.download('punkt_tab')

print("Semua library berhasil diimport!")
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Semua library berhasil diimport!

# %%
# Load dataset
df = pd.read_csv('/content/data/raw/combined_data.csv')

print("Dataset berhasil diupload!")
print(f"Shape dataset: {df.shape}")
print(f"Kolom yang tersedia: {list(df.columns)}")
display(df.head(10))
# Out:
# Dataset berhasil diupload!
# Shape dataset: (3272, 15)
# Kolom yang tersedia: ['conversation_id_str', 'created_at', 'favorite_count', 'full_text', 'id_str', 'image_url', 'in_reply_to_screen_name', 'lang', 'location', 'quote_count', 'reply_count', 'retweet_count', 'tweet_url', 'user_id_str', 'username']
#    conversation_id_str                      created_at  favorite_count  \
# 0  1962299990761734245  Sun Aug 31 23:42:30 +0000 2025               0
# 1  1962298947650920833  Sun Aug 31 23:38:21 +0000 2025               1
# 2  1962296611000000927  Sun Aug 31 23:29:04 +0000 2025              16
# 3  1962285953726509097  Sun Aug 31 22:46:43 +0000 2025               1
# 4  1962179468489113897  Sun Aug 31 22:33:25 +0000 2025               0
# 5  1961745502762078665  Sun Aug 31 18:34:54 +0000 2025               0
# 6  1961626746744443281  Sun Aug 31 16:50:43 +0000 2025               0
# 7  1962186910639817124  Sun Aug 31 16:13:09 +0000 2025               1
# 8  1962157841952969209  Sun Aug 31 16:02:38 +0000 2025               0
# 9  1962177559460012253  Sun Aug 31 15:37:34 +0000 2025               0
#
#                                            full_text               id_str  \
# 0  tapi sumpah guyss jgn rusak fasilitas umum kar...  1962299990761734245
# 1  Beneran gw pas jalan kerja di gojek nangis sed...  1962298947650920833
# 2  Mobil Dinas Kesulitan di Jalan Rusak Warga Pil...  1962296611000000927
# 3  helehhhh prett bgt orang jepara aslinya gamau ...  1962285953726509097
# 4  @yorselves Apakah adil rakyat yg mati gegara l...  1962282606768341410
# 5  @alisyarief Jangan rusak fasilitas tapi kejar ...  1962222581517537415
# 6  @SwaggyMoYT @Elektroo12_ ANJINK GOBLOK. Dari d...  1962196362034049306
# 7  Stay safe ges yg mau ikut turun besok. Sekolah...  1962186910639817124
# 8  @kanggalongratis Ga diliburin kah rijjak? Seko...  1962184263245451361
# 9  @budiwsso Berdasarkan info terkini dari berita...  1962177954617979057
#
#   image_url in_reply_to_screen_name lang  location  quote_count  reply_count  \
# 0       NaN                     NaN   in       NaN            0            0
# 1       NaN                     NaN   in       NaN            0            0
# 2       NaN                     NaN   in       NaN            1            1
# 3       NaN                     NaN   in       NaN            0            0
# 4       NaN               yorselves   in       NaN            0            0
# 5       NaN              alisyarief   in       NaN            0            0
# 6       NaN         busetwaduhkacau   in       NaN            0            1
# 7       NaN                     NaN   in       NaN            0            1
# 8       NaN         kanggalongratis   in       NaN            0            1
# 9       NaN                budiwsso   in       NaN            0            0
#
#    retweet_count                                          tweet_url  \
# 0              0  https://x.com/undefined/status/196229999076173...
# 1              0  https://x.com/undefined/status/196229894765092...
# 2              2  https://x.com/undefined/status/196229661100000...
# 3              0  https://x.com/undefined/status/196228595372650...
# 4              0  https://x.com/undefined/status/196228260676834...
# 5              0  https://x.com/undefined/status/196222258151753...
# 6              0  https://x.com/undefined/status/196219636203404...
# 7              0  https://x.com/undefined/status/196218691063981...
# 8              0  https://x.com/undefined/status/196218426324545...
# 9              0  https://x.com/undefined/status/196217795461797...
#
#            user_id_str  username
# 0  1693985563450433536       NaN
# 1  1574439522053804032       NaN
# 2             41730943       NaN
# 3  1121031670289690625       NaN
# 4           1393643270       NaN
# 5  1855268187392323584       NaN
# 6  1509411039187718147       NaN
# 7  1127213416995741699       NaN
# 8  1733521150263877632       NaN
# 9  1720665183188922368       NaN

# %%
# Create a new DataFrame with selected columns
cleaned_df = combined_df[['created_at', 'full_text']].copy()

# Rename columns for clarity (optional, but good practice)
cleaned_df = cleaned_df.rename(columns={
    'full_text': 'text'
})

# Define the output path for the new CSV file
output_cleaned_filepath = os.path.join(PROCESSED_DIR, 'cleaned_combined_data.csv') # Use PROCESSED_DIR

# Save the new DataFrame to a CSV file
cleaned_df.to_csv(output_cleaned_filepath, index=False)

print(f"Cleaned data saved to: {output_cleaned_filepath}")

# Display the first few rows of the new DataFrame
display(cleaned_df.head())

# Print the shape of the new DataFrame
print(f"Shape of the cleaned DataFrame: {cleaned_df.shape}")
# Out:
# Cleaned data saved to: /content/data/processed/cleaned_combined_data.csv
#                        created_at  \
# 0  Sun Aug 31 23:42:30 +0000 2025
# 1  Sun Aug 31 23:38:21 +0000 2025
# 2  Sun Aug 31 23:29:04 +0000 2025
# 3  Sun Aug 31 22:46:43 +0000 2025
# 4  Sun Aug 31 22:33:25 +0000 2025
#
#                                                 text
# 0  tapi sumpah guyss jgn rusak fasilitas umum kar...
# 1  Beneran gw pas jalan kerja di gojek nangis sed...
# 2  Mobil Dinas Kesulitan di Jalan Rusak Warga Pil...
# 3  helehhhh prett bgt orang jepara aslinya gamau ...
# 4  @yorselves Apakah adil rakyat yg mati gegara l...
# Shape of the cleaned DataFrame: (3272, 2)

# %%
import os, re, random
import numpy as np
import pandas as pd
import emoji
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nlp_id.tokenizer import Tokenizer
from nlp_id.stopword import StopWord



# === Tools NLP Indonesia ===
tokenizer_nlp = Tokenizer()
stopwords = set(StopWord().get_stopword())
stemmer = StemmerFactory().create_stemmer()

# === Slang Dictionary ===
def load_slang_dict(file_path="/content/slangword.txt"):
    slang_dict = {}
    if os.path.exists(file_path):
        with open(file_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line or ':' not in line:
                    continue
                slang, meaning = line.split(':', 1)
                slang_dict[slang.strip().lower()] = meaning.strip().lower()
    return slang_dict

slang_dict = load_slang_dict()

def mapping_slang(tokens, slang_dict):
    return [slang_dict.get(w.lower(), w) for w in tokens]

# === Regex Utility ===
URL_RE = re.compile(r'https?://\S+')
HANDLE_RE = re.compile(r'@\w+')
WHITESPACE_RE = re.compile(r'\s+')

# === Clean + Preprocess ===
def clean_text(text: str) -> str:
    """
    Gabungan fungsi clean_text lama + preprocess_text
    """
    # Handling missing values
    if not isinstance(text, str):
        return ""

    # --- Step 1: Basic cleaning (dari kode lama)
    text = URL_RE.sub(" <URL> ", text)
    text = HANDLE_RE.sub(" <USER> ", text)
    text = WHITESPACE_RE.sub(" ", text).strip()

    # --- Step 2: Case folding
    text = text.lower()

    # --- Step 3: Remove URLs, mentions, emoji, hashtags
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = emoji.replace_emoji(text, replace="")
    text = re.sub(r"#\w+", "", text)
    text = re.sub(r"&amp;", "dan", text)

    # --- Step 4: Remove special characters + angka, normalize repeated chars
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"(.)\1{2,}", r"\1", text)

    # --- Step 5: Tokenization
    tokens = tokenizer_nlp.tokenize(text)

    # --- Step 6: Slang mapping
    tokens = mapping_slang(tokens, slang_dict)

    # --- Step 7: Stopword removal + filter kata pendek
    tokens = [w for w in tokens if w not in stopwords and len(w) > 2]

    # --- Step 8: Stemming (Sastrawi)
    tokens = [stemmer.stem(w) for w in tokens]

    return " ".join(tokens)

print("✅ Fungsi clean_text siap dengan slang mapping, stopword removal, dan stemming!")
# Out:
# ✅ Fungsi clean_text siap dengan slang mapping, stopword removal, dan stemming!

# %%
# Terapkan Preprocessing pada Data
print("Sedang melakukan preprocessing teks...")

# Terapkan preprocessing pada kolom text
tqdm.pandas()
cleaned_df['cleaned_text'] = cleaned_df['text'].progress_apply(clean_text)

print("Preprocessing selesai!")
display(cleaned_df.head())
# Out:
# Sedang melakukan preprocessing teks...
# 100%|██████████| 3272/3272 [14:39<00:00,  3.72it/s]
# Preprocessing selesai!
#                        created_at  \
# 0  Sun Aug 31 23:42:30 +0000 2025
# 1  Sun Aug 31 23:38:21 +0000 2025
# 2  Sun Aug 31 23:29:04 +0000 2025
# 3  Sun Aug 31 22:46:43 +0000 2025
# 4  Sun Aug 31 22:33:25 +0000 2025
#
#                                                 text  \
# 0  tapi sumpah guyss jgn rusak fasilitas umum kar...
# 1  Beneran gw pas jalan kerja di gojek nangis sed...
# 2  Mobil Dinas Kesulitan di Jalan Rusak Warga Pil...
# 3  helehhhh prett bgt orang jepara aslinya gamau ...
# 4  @yorselves Apakah adil rakyat yg mati gegara l...
#
#                                         cleaned_text
# 0  sumpah guyss rusak fasilitas kitaa pakai rambu...
# 1  beneran jalan kerja gojek nang sedih lihat hal...
# 2  mobil dinas sulit jalan rusak warga pilih reka...
# 3  heleh prett orang jepara asli gamau ribet pusi...
# 4  user adil rakyat mati gegara lubang jalan kual...

# %%
# Define the output path for the preprocessed data
output_preprocessed_filepath = os.path.join(PROCESSED_DIR, 'preprocessed_data.csv')

# Save the cleaned DataFrame with the new 'cleaned_text' column to a CSV file
cleaned_df.to_csv(output_preprocessed_filepath, index=False)

print(f"Preprocessed data saved to: {output_preprocessed_filepath}")
# Out:
# Preprocessed data saved to: /content/data/processed/preprocessed_data.csv
